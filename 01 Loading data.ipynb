# %%
import pandas as pd

# %%
# Loading data with different formats into Pandas DateFrame
# CSV, JSON, HTML, Excel, SAS, SQL, Google Big Query,...

# %%
# Data formats that Pandas supports: 
# https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html

# %% [markdown]
# ### Loading data from csv for file IMDb data set [1]

# %%
# df_csv = pd.read_csv('C:/Users/admin/Downloads/Practival Data Analysis with Python Pandas Real Project/Movie+Assignment+Data.csv')
df_csv = pd.read_csv('Movie+Assignment+Data.csv')
df_csv.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %%
# Check the shape of dataframe
df_csv.shape
# Out:
# (100, 62)

# %%
# Check the info of the dataframe
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
# Check summary for the numeric columns
df_csv.describe(include = 'all')
# Out:
#                      Title   title_year        budget         Gross  \
# count                  100   100.000000  1.000000e+02  1.000000e+02
# unique                 100          NaN           NaN           NaN
# top     X-Men: First Class          NaN           NaN           NaN
# freq                     1          NaN           NaN           NaN
# mean                   NaN  2012.820000  7.838400e+07  1.468679e+08
# std                    NaN     1.919491  7.445295e+07  1.454004e+08
# min                    NaN  2010.000000  3.000000e+06  2.238380e+05
# 25%                    NaN  2011.000000  1.575000e+07  4.199752e+07
# 50%                    NaN  2013.000000  4.225000e+07  1.070266e+08
# 75%                    NaN  2014.000000  1.500000e+08  2.107548e+08
# max                    NaN  2016.000000  2.600000e+08  9.366622e+08
#
#              actor_1_name   actor_2_name   actor_3_name  \
# count                 100            100            100
# ...

# %% [markdown]
# ### Loading data from excel for file IMDb data set [1]

# %%
df_excel = pd.read_excel('Movie+Assignment+Data.xlsx')
df_excel.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone      AmiÃ©e Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %% [markdown]
# ### Loading data from html on CoinMarketCap

# %%
df_html = pd.read_html('https://coinmarketcap.com/')
df_html[0].head() # df_html has only one return table, so set the index as 0
# Out:
#    Unnamed: 0    #                 Name       Price  24h %    7d %  \
# 0         NaN  1.0       Bitcoin1BTCBuy  $49,672.68  4.88%   5.86%
# 1         NaN  2.0      Ethereum2ETHBuy   $3,765.73  6.03%  20.69%
# 2         NaN  3.0          Cardano3ADA       $2.96  4.58%  15.15%
# 3         NaN  4.0  Binance Coin4BNBBuy     $484.60  1.27%   0.14%
# 4         NaN  5.0       Tether5USDTBuy          $1  0.03%   0.04%
#
#                  Market Cap                         Volume(24h)  \
# 0  $934.07B$934,065,829,707          $39,319,728,613791,577 BTC
# 1  $441.94B$441,942,640,857        $27,345,103,1307,261,572 ETH
# 2    $95.22B$95,215,305,378     $7,369,594,7052,488,026,337 ADA
# 3    $81.48B$81,479,133,873         $2,500,611,9565,160,161 BNB
# 4    $65.75B$65,752,658,311  $85,416,702,32885,419,326,037 USDT
#
#     Circulating Supply  Last 7 Days  Unnamed: 10
# 0       18,804,418 BTC          NaN          NaN
# 1      117,359,155 ETH          NaN          NaN
# ...

# %% [markdown]
# ### Loading data from Python dictionary

# %%
movieData = {
    'Title' : ['La La Land', 'Zootopia', 'Lion'],
    'title_year' : [2016, 2016, 2016],
    'budget' : [30000000, 150000000, 12000000],
    'actor_1_name' : ['Ryan Gosling', 'Ginnifer Goodwin', 'Dev Patel']
}
df_dic = pd.DataFrame(movieData)
df_dic
# Out:
#         Title  title_year     budget      actor_1_name
# 0  La La Land        2016   30000000      Ryan Gosling
# 1    Zootopia        2016  150000000  Ginnifer Goodwin
# 2        Lion        2016   12000000         Dev Patel

# %% [markdown]
# ### Reference
# 1. https://drive.google.com/drive/folders/1WiD9EC0Qqc_bWdn93-_kxYtiP48Wlb-v
